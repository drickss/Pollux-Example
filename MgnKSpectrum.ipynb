# %%
import astropy.table as Table 
import numpy as np
from astropy.io import fits

data = fits.open("/Users/dricks/daijas_project/140313003601012_allstar_fit_spectrum.fits")
data[1].data
# Out:
# FITS_rec([(4713.51889855, 0.95731171, 0.02018312, 0.99643421, True),
#           (4713.56489443, 0.96973316, 0.0202414 , 0.99618494, True),
#           (4713.61089032, 0.99157641, 0.02043293, 0.99514791, True), ...,
#           (7885.78714857, 1.03191451, 0.01555773, 0.99960563, True),
#           (7885.86064675, 1.09137322, 0.01592692, 0.99956685, True),
#           (7885.93414493, 1.13661677, 0.01622238, 0.99953662, True)],
#          dtype=(numpy.record, [('wave', '>f8'), ('sob', '>f8'), ('uob', '>f8'), ('smod', '>f8'), ('mob', 'i1')]))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.xlim(7690, 7710)
plt.ylim(0.7, 1.2)
plt.plot(data[1].data["wave"], data[1].data["sob"], label="Observed Spectrum", color="blue")
plt.plot(data[1].data["wave"], data[1].data["smod"], label="Model Spectrum", color="cyan", linestyle="--")
plt.xlabel("Wavelength (Angstroms)")
plt.ylabel("Flux")
plt.title("Mg and K Spectrum")
plt.grid(True)
plt.legend()
plt.show()
